# %% [markdown]
# ## Consultar los trabajos de GetOnBoard con Python3
#
# El siguiente programa utiliza los datos de trabajos de programación de la página GetOnBoard para mostrarlos en un DataFrame, filtrarlos y luego graficar los resultados filtrados.
#
# ## Preparativos
# Primero, instalamos e importamos las bibliotecas necesarias: pandas para manejar los datos en un DataFrame, requests para realizar llamadas a la API, re para manipular texto y matplotlib para graficar.
# ```
# ! pip install pandas,requests,matplotlib
#
# import pandas as pd
# import requests
# import re
# import matplotlib.pyplot
# ```
#
# Luego, definimos una función para limpiar los datos que contengan etiquetas HTML.
#
#
# ```
# def remove_html_tags(text):
#     clean_text = re.sub(r'<[^>]*>', ' ', str(text))
#     return clean_text
# ```
#
# Finalmente, definimos una función para filtrar trabajos por palabras clave.
#
#
# ```
# def filter_jobs_by_keyword(df, keywords):
#     filtered_df = pd.DataFrame()
#     for keyword in keywords:
#             filtered_df = pd.concat([filtered_df, df[df['desirable'].str.contains(keyword, case=False, na=False)]])
#     return filtered_df
#
# ```
#
# ## Flujo de código
#
# A continuación se mostrará el código del programa explicando brevemente lo que realiza.
#
# ## Llamada a la API y normalización de datos
#
# Primero, realizamos una llamada a la API de GetOnBoard y normalizamos los datos con pandas.
#
#
# ```
# response = requests.get('https://www.getonbrd.com/api/v0/categories/programming/jobs')
# responseInJSON = response.json();
# data = responseInJSON['data'];
# df = pd.json_normalize(data);
#
# ```
#
# Es importante mencionar que el metodo .json_normalize ya crea un dataframe normalizado.
#
# ## Limpieza de datos
#
# Los datos de "functions" y "derisable" que entrega esta API están sucios con etiquetas HTML dentro del JSON, por lo tanto, para una mejor lectura es mejor limpiar esos datos. Aquí utilizamos la función antes definida para limpiar etiquetas HTML.
#
# ```
# df['attributes.functions'] = df['attributes.functions'].apply(remove_html_tags);
# df['attributes.desirable'] = df['attributes.desirable'].apply(remove_html_tags);
# ```
# ## Construir el Dataframe
#
# Primero definiremos un arreglo con las columnas que necesitamos para el muestreo de datos, en este caso se eligen las siguientes.
#
# ```
# columns_to_select = ['attributes.title', 'attributes.functions', 'attributes.desirable',
#                      'attributes.min_salary', 'attributes.max_salary', 'attributes.modality']
# ```
# Luego, se verifica si es que la columna de "modality" es nula o no, debido a que varios trabajos que entrega la API no presentan este dato. Si se encuentra un dato nulo en modality, se elimina la columna. (puedes reemplazar este comportamiento por lo que tu quieras). Y finalmente se imprime el dataframe creado.
#
# ```
# if 'attributes.modality' in df.columns:
#     finalDf= df[columns_to_select]
#     finalDf = df[[col for col in columns_to_select]]
#     finalDf.columns=['title', 'functions', 'desirable', 'min_salary', 'max_salary']
# else:
#     columns_to_select.remove('attributes.modality')
#     finalDf = df[[col for col in columns_to_select]]
#     finalDf.columns=['title', 'functions', 'desirable', 'min_salary', 'max_salary']
#
# finalDf
# ```
# Con esto ya tenemos nuestro primer dataframe mostrando todos los trabajos con las columnas que quisimos mostrar.
#
# ## Filtrado por palabra
#
# Primero, eliminaremos cualquier fila que tenga como "max_salary" NaN, ya que, en este caso nos interesa saber cuanto es el salario máximo que puede ganar un programador en base a las funciones que deba ejercer.
#
# ```
# cleaned_df = finalDf.dropna(subset=['min_salary', 'max_salary'])
#
# ```
#
# Luego, utilizamos la funcion filter_jobs_by_keyword() creada anteriormente para filtrar por palabras.
#
# ```
# filtered_jobs = filter_jobs_by_keyword(cleaned_df,["Scrum","Microservicios","MongoDB"," .NET ", "Java"]);
# filtered_jobs
# ```
#
# ## Gráfico
#
# Para finalizar, utilizamos matplotlib.pyplot para graficar los datos filtrados.
#
# El parámetro figsize especifica las dimensiones de la figura en pulgadas (ancho, alto). En este caso, (10, 6) indica que la figura tendrá 10 pulgadas de ancho y 6 pulgadas de alto.
#
# ```
# plt.figure(figsize=(10, 6))
# ```
#
# Luego, le indicamos al gráfico de barras quien será su eje x y quien será su eje Y. Se rota el label para los elementos del eje x en 45 grados para una mejor lectura y visibilidad, y finalmente se muestra el gráfico.
#
# ```
# plt.bar(filtered_jobs['title'], filtered_jobs['max_salary'], color='skyblue')
# plt.xticks(rotation=45, ha='right')
# plt.show()
# ```

# %%
# %pip install pandas
# %pip install requests
# %pip install matplotlib

# %%
import sys
print(sys.executable)

# %%
import pandas as pd
import re
import requests
import matplotlib.pyplot as plt

# %%
def remove_html_tags(text):
    clean_text = re.sub(r'<[^>]*>', ' ', str(text))
    return clean_text

# %%
response = requests.get('https://www.getonbrd.com/api/v0/categories/programming/jobs')
responseInJSON = response.json();
data = responseInJSON['data'];
df = pd.json_normalize(data);

# %%
df['attributes.functions'] = df['attributes.functions'].apply(remove_html_tags);
df['attributes.desirable'] = df['attributes.desirable'].apply(remove_html_tags);

# %%
columns_to_select = ['attributes.title', 'attributes.functions', 'attributes.desirable', 
                     'attributes.min_salary', 'attributes.max_salary', 'attributes.modality']

if 'attributes.modality' in df.columns:
    finalDf= df[columns_to_select]
    finalDf = df[[col for col in columns_to_select]]
    finalDf.columns=['title', 'functions', 'desirable', 'min_salary', 'max_salary']
else:
    columns_to_select.remove('attributes.modality')
    finalDf = df[[col for col in columns_to_select]]
    finalDf.columns=['title', 'functions', 'desirable', 'min_salary', 'max_salary']
    
finalDf

# %%
def filter_jobs_by_keyword(df, keywords, column):
    filtered_df = pd.DataFrame()
    for keyword in keywords:
            filtered_df = pd.concat([filtered_df, df[df[column].str.contains(keyword, case=False, na=False)]])
    return filtered_df

# %%
request = requests.get("https://www.getonbrd.com/api/v0/categories?per_page=100&page=1");
dataJson = request.json();
data = dataJson['data'];
categories = []
for element in data:
    categories.append(element['id']);
categories

# %%
len(categories)

# %%
response2 = []
for cat in categories:
    request2 = (requests.get(f'https://www.getonbrd.com/api/v0/categories/{cat}/jobs?expand=["tags"]'))
    response2.append(request2.json()['data'])
response2

# %%
ultimateDf = pd.DataFrame(response2)
ultimateDf

# %%
ultimateDf.to_csv( 'trabajitos' , index=False);

# %%
jobs = []
for i in range(len(categories)):
    for j in range(len(response2[i])):
        jobs.append(response2[i][j])
jobs

# %%
jobsDf = pd.json_normalize(jobs)
jobsDf = jobsDf.drop(['type','id','attributes.projects', 'attributes.description_headline', 'attributes.location_tenants.data', 'attributes.location_cities.data'], axis=1) # Drop innecesary columns, sacar headlines y campos sin información
jobsDf['attributes.functions'] = jobsDf['attributes.functions'].apply(remove_html_tags);
jobsDf['attributes.benefits'] = jobsDf['attributes.benefits'].apply(remove_html_tags);
jobsDf['attributes.description'] = jobsDf['attributes.description'].apply(remove_html_tags);
jobsDf

# %%
print(jobsDf['attributes.tags.data'])

# %% [markdown]
# # Información General
# 1. ¿Cuántas categorías de trabajos hay en el dataset?

# %%
print("Existen",len(categories), "categorias de trabajos en el dataset")

# %% [markdown]
# 2.¿Cuántos trabajos hay en total en el dataset?

# %%
print("Hay un total de", jobsDf['attributes.title'].size, "trabajos en el dataset" )

# %% [markdown]
# 3.¿Cuál es la categoría con más ofertas de trabajo?

# %%
#.sort_values(ascending=False) ordena los valores de esta columna en orden descendente (de mayor a menor).
# .index devuelve los índices de los valores ordenados
aplicationsSort = jobsDf['attributes.applications_count'].sort_values(ascending=False).index
print("El trabajo con más aplicaciones es", jobsDf['attributes.title'][aplicationsSort[0]], "con", jobsDf['attributes.applications_count'][aplicationsSort[0]], "aplicaciones")

# %% [markdown]
# 4.¿Cuál es la categoría con menos ofertas de trabajo?

# %%
#.sort_values(ascending=True) ordena los valores de esta columna en orden ascendente (de menor a mayor)., en este caso se revisó
#que el trabajo con menos aplicaciones es 0 por lo que se buscaron todos los trabajos con este numero de aplicaciones en vez de utilizar .sort_values(ascending=True)
# .index devuelve los índices de los valores ordenados
jobsWithouAplications = jobsDf[jobsDf['attributes.applications_count'] == 0] # Se filtran los trabajos con 0 aplicaciones :D
print("Hay", jobsWithouAplications['attributes.title'].size, "trabajos sin aplicaciones")
print("La lista de trabajos sin aplicaciones es:"," \n " ,jobsWithouAplications['attributes.title'].values,"\n"
      "con un total de", jobsWithouAplications['attributes.applications_count'].values[0], "aplicaciones cada uno")

# %% [markdown]
# # Detalles por Trabajo
# 5. ¿Cuáles son los títulos de todos los trabajos en la categoría de 'Programming'?

# %%
# Se filtran los trabajos que contienen las palabras 'Programador', 'Desarrollador' o 'Developer' en su título, 
#case=False para que no sea sensible a mayúsculas y minúsculas, na=False para que no tome en cuenta los valores nulos
programingTitles = jobsDf[jobsDf['attributes.title'].str.contains("Programador|Desarrollador|Developer|Programming", case=False, na=False)] 
print("Hay", programingTitles['attributes.title'].size, "trabajos que contienen las palabras 'Programador', 'Desarrollador', 'Developer' o 'Programming' en su título")

# %% [markdown]
# 6.¿Qué porcentaje de trabajos requieren experiencia en 'Remote' o 'Hybrid' en comparación con los trabajos presenciales?

# %%
remoteJobs = jobsDf[jobsDf['attributes.remote'] == True] # Se filtran los trabajos que son remotos
print("Hay", remoteJobs['attributes.title'].size, "trabajos remotos")
hybridJobs = jobsDf[jobsDf['attributes.remote_modality'] == 'hybrid'] # Se filtran los trabajos que son híbridos
print("Hay", hybridJobs['attributes.title'].size, "trabajos híbridos")
presentialJobs = jobsDf[(jobsDf['attributes.remote'] == False) & (jobsDf['attributes.remote_modality'] != 'hybrid')] # Se filtran los trabajos que son presenciales
print("Hay", presentialJobs['attributes.title'].size, "trabajos presenciales")

totalRemoteHybridJobs = remoteJobs['attributes.title'].size + hybridJobs['attributes.title'].size
presentialJobs = presentialJobs['attributes.title'].size

print("Hay", totalRemoteHybridJobs, "trabajos que requieren experiencia en remoto o híbrido")
if presentialJobs > 0:  # Evitar división por cero pofavo
    porcentajeRH = (totalRemoteHybridJobs/(presentialJobs+totalRemoteHybridJobs)) * 100;
    porcentajeP = (presentialJobs/(presentialJobs+totalRemoteHybridJobs))*100;
    print("El porcentaje de trabajos que requieren experiencia en remoto o híbrido es ", porcentajeRH,"%");
    print("El porcentaje de trabajos que requieren experiencia en presencial es ", porcentajeP,"%");
else:
    print("No hay trabajos presenciales para comparar.")

# %% [markdown]
# 7.¿Cuáles son las tres habilidades más comúnmente solicitadas en la categoría de 'Data Science / Analytics'?

# %%
dfDataScienceAnalytics = filter_jobs_by_keyword(jobsDf,['Data Science / Analytics'],'attributes.category_name')
dfDataScienceAnalytics

# %%
from collections import Counter;
tag_counter = Counter()

# Iterar sobre cada fila del dataframe
for _, row in dfDataScienceAnalytics.iterrows():
    tags = row["attributes.tags.data"]
    for tag in tags:
        tag_id = tag['id']
        tag_counter[tag_id] += 1

# Obtener los 3 tags más frecuentes
most_common_tags = tag_counter.most_common(3)

# Mostrar los resultados
print(most_common_tags)

# %%
dfCert = filter_jobs_by_keyword(jobsDf,['certifi'],'attributes.description');
dfCert

# %%
dfCert.shape

# %% [markdown]
# ## 46 registros que solicitan certificaciones

# %% [markdown]
# ## Pregunta 4

# %%
tag_counter = 0

# Iterar sobre cada fila del dataframe
for _, row in jobsDf.iterrows():
    tags = row["attributes.tags.data"]
    for tag in tags:
        tag_id = tag['id']
        if (tag_id == "english"):
            tag_counter += 1;

print((tag_counter/jobsDf.shape[0])*100, "%")

# %%
dfExp = filter_jobs_by_keyword(jobsDf,['experiencia previa'],'attributes.description');
dfExp2 = filter_jobs_by_keyword(jobsDf,['experiencia previa'],'attributes.desirable');

dfExp.shape[0]+dfExp2.shape[0]

# %%
categories

# %%
dfUX = filter_jobs_by_keyword(jobsDf,['Design / UX'],'attributes.category_name')
dfUX

# %%
jobsDf

# %%
print(jobsDf['attributes.tags.data'].tolist()[0])

# %%
tagsArray = []
nan = float('nan')
for _, row in jobsDf.iterrows():
    tagInJob = []
    tags = row["attributes.tags.data"]
    salary = ((row['attributes.max_salary']+row['attributes.min_salary'])/2)
    pais = row['attributes.countries']
    binary = "mayor que mil" if salary>1500 else "menor que 1500"
    title = row["attributes.title"]
    if tags and pd.notna(salary):
        for tag in tags:
            tagInJob.append(tag['id'])
        tagsArray.append(tagInJob)
        tagInJob.append(binary)
        tagInJob.append(title)
        tagInJob.append(pais[0])
        
tagsArray
# Out:
# [['excel',
#   'customer-service',
#   'crm',
#   'hubspot',
#   'customer-success',
#   'menor que 1500',
#   'Agente de Customer Success',
#   'Remote'],
#  ['excel', 'menor que 1500', 'Customer Implementation Specialist', 'Remote'],
#  ['excel',
#   'customer-service',
#   'english',
#   'customer-success',
#   'menor que 1500',
#   'Customer Success Executive',
#   'Chile'],
#  ['javascript',
#   'python',
#   'agile',
#   'front-end',
#   'angularjs',
#   'virtualization',
#   'react',
#   'amazon-web-services',
#   'docker',
#   'kubernetes',
#   'cloud-computing',
#   'back-end',
#   'ci-cd',
#   'cloud',
#   'angular',
#   'menor que 1500',
#   'Programador Junior Soporte de Soluciones Cloud',
#   'Peru'],
#  ['onboarding-specialist',
#   'menor que 1500',
#   'Onboarding Specialist Mexico',
#   'Remote'],
#  ['saas',
#   'customer-success',
#   'mayor que mil',
#   'Customer Success Manager México',
#   'Remote'],
#  ['customer-success',
#   'menor que 1500',
#   'Customer Success Onboarding',
#   'Chile'],
#  ['excel', 'menor que 1500', 'Fleet Assistant (Soporte Terreno)', 'Chile'],
#  ['ingeniero-comercial',
#   'english',
#   'security-engineer',
#   'cloud',
#   'mayor que mil',
#   'Vendedor/a Ciberseguridad con Foco en Cliente',
#   'Chile'],
#  ['customer-service',
#   'crm',
#   'jira',
#   'hubspot',
#   'menor que 1500',
#   'Agente de Soporte',
#   'Remote'],
#  ['customer-success',
#   'menor que 1500',
#   'Customer Success Onboarding',
#   'Mexico'],
#  ['javascript',
#   'ux',
#   'diseno-ui',
#   'html5',
#   'css',
#   'agile',
#   'lean',
#   'diseno-web',
#   'graphic-design',
#   'design-thinking',
#   'figma',
#   'menor que 1500',
#   'UI Designer (Santiago)',
#   'Chile'],
#  ['ux',
#   'diseno-ui',
#   'html5',
#   'css',
#   'agile',
#   'front-end',
#   'diseno-web',
#   'scrum',
#   'sketch',
#   'english',
#   'figma',
#   'menor que 1500',
#   'Diseñador UX',
#   'Remote'],
#  ['english', 'menor que 1500', 'Editorial Designer', 'Remote'],
#  ['diseno-ui',
#   'diseno-web',
#   'graphic-design',
#   'menor que 1500',
#   'Diseñador/a Gráfico/a',
#   'Remote'],
#  ['diseno-ui',
#   'diseno-web',
#   'graphic-design',
#   'menor que 1500',
#   'Graphic Designer',
#   'Remote'],
#  ['ux',
#   'diseno-ui',
#   'diseno-web',
#   'adobe-suite',
#   'figma',
#   'menor que 1500',
#   'Diseño UX/UI',
#   'Remote'],
#  ['javascript',
#   'ux',
#   'front-end',
#   'angularjs',
#   'graphic-design',
#   'angular',
#   'mayor que mil',
#   'Diseño UX/UI',
#   'Chile'],
#  ['ux',
#   'diseno-ui',
#   'analytics',
#   'diseno-web',
#   'service-design',
#   'design-thinking',
#   'wireframes',
#   'research',
#   'figma',
#   'jira',
#   'user-testing',
#   'menor que 1500',
#   'Diseñador UX UI',
#   'Chile'],
#  ['ux',
#   'diseno-ui',
#   'analytics',
#   'agile',
#   'diseno-web',
#   'figma',
#   'mayor que mil',
#   'UX Team Lead',
#   'Remote'],
#  ['html5',
#   'css',
#   'git',
#   'bootstrap',
#   'react',
#   'next-js',
#   'javascript',
#   'menor que 1500',
#   'Programador Web Front-end Nextjs',
#   'Chile'],
#  ['sql',
#   'c-sharp',
#   'angularjs',
#   'c',
#   'net',
#   'mvc',
#   'back-end',
#   'javascript',
#   'angular',
#   'front-end',
#   'visual-basic',
#   'mayor que mil',
#   'Desarrollador Web .NET',
#   'Chile'],
#  ['sql',
#   'ux',
#   'c-sharp',
#   'angularjs',
#   'c',
#   'react',
#   'sql-server',
#   'back-end',
#   'javascript',
#   'angular',
#   'front-end',
#   'continual-improvement-process',
#   'mayor que mil',
#   'Programador',
#   'Chile'],
#  ['web-server',
#   'sql',
#   'python',
#   'bigquery',
#   'data-architecture',
#   'apache-spark',
#   'spark',
#   'cloud-gcp',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'english',
#   'data-engineer',
#   'terraform',
#   'cloud',
#   'infrastructure-as-code',
#   'mayor que mil',
#   'Data Engineer! 🚀',
#   'Chile'],
#  ['json',
#   'continuous-integration',
#   'python',
#   'virtualization',
#   'docker',
#   'git',
#   'jenkins',
#   'api',
#   'back-end',
#   'ci-cd',
#   'soap',
#   'linux',
#   'mayor que mil',
#   'Desarrollador de Integraciones Wso2',
#   'Chile'],
#  ['mysql',
#   'sql',
#   'php',
#   'vue-js',
#   'git',
#   'sql-server',
#   'full-stack',
#   'back-end',
#   'laravel',
#   'api',
#   'mayor que mil',
#   'Desarrollador Full-Stack PHP',
#   'Chile'],
#  ['ruby-on-rails',
#   'git',
#   'user-testing',
#   'mayor que mil',
#   'Ruby on Rails Developer',
#   'Remote'],
#  ['cto', 'english', 'mayor que mil', 'CTO', 'Chile'],
#  ['wordpress',
#   'jquery',
#   'html5',
#   'php',
#   'css',
#   'e-commerce',
#   'jira',
#   'back-end',
#   'agile',
#   'javascript',
#   'bitbucket',
#   'mayor que mil',
#   'WordPress Developer – Woocommerce Specialist',
#   'Remote'],
#  ['mysql',
#   'nosql',
#   'nestjs',
#   'node-js',
#   'angularjs',
#   'oracle',
#   'go',
#   'postgresql',
#   'virtualization',
#   'golang',
#   'mongodb',
#   'amazon-web-services',
#   'full-stack',
#   'back-end',
#   'firebase',
#   'mobile',
#   'cloud-computing',
#   'typescript',
#   'javascript',
#   'cloud',
#   'angular',
#   'front-end',
#   'mayor que mil',
#   'Jefe/a Programación Full-Stack',
#   'Chile'],
#  ['svn',
#   'node-js',
#   'angularjs',
#   'html5',
#   'oracle',
#   'css',
#   'maven',
#   'git',
#   'bootstrap',
#   'spring',
#   'full-stack',
#   'back-end',
#   'tomcat',
#   'javascript',
#   'angular',
#   'java',
#   'front-end',
#   'spring-boot',
#   'project-management',
#   'mayor que mil',
#   'Full-Stack Angular + Java',
#   'Peru'],
#  ['fastapi',
#   'django',
#   'continuous-integration',
#   'python',
#   'react',
#   'back-end',
#   'ci-cd',
#   'javascript',
#   'mayor que mil',
#   'Senior Software Engineer',
#   'Remote'],
#  ['jquery',
#   'html5',
#   'php',
#   'python',
#   'css',
#   'virtualization',
#   'docker',
#   'git',
#   'bootstrap',
#   'api',
#   'full-stack',
#   'back-end',
#   'mobile',
#   'android',
#   'javascript',
#   'mayor que mil',
#   'Programador Full-Stack Senior',
#   'Chile'],
#  ['sql',
#   'virtualization',
#   'data-architecture',
#   'amazon-web-services',
#   'cloud-computing',
#   'data-engineer',
#   'cloud',
#   'security-engineer',
#   'mayor que mil',
#   'Ingeniero de Datos',
#   'Remote'],
#  ['ruby',
#   'ruby-on-rails',
#   'python',
#   'vue-js',
#   'react',
#   'full-stack',
#   'back-end',
#   'javascript',
#   'front-end',
#   'menor que 1500',
#   'Práctica o Título Desarrollador Full-Stack',
#   'Chile'],
#  ['redis',
#   'svn',
#   'nosql',
#   'node-js',
#   'mongodb',
#   'git',
#   'couchdb',
#   'back-end',
#   'agile',
#   'javascript',
#   'continuous-integration',
#   'virtualization',
#   'docker',
#   'microservices',
#   'kubernetes',
#   'jenkins',
#   'api',
#   'tdd',
#   'bdd',
#   'mayor que mil',
#   'Developer Back-end',
#   'Chile'],
#  ['apex',
#   'crm',
#   'salesforce',
#   'back-end',
#   'java',
#   'api',
#   'rest',
#   'soap',
#   'web-service',
#   'mayor que mil',
#   'Desarrollador@ Salesforce',
#   'Remote'],
#  ['django',
#   'python',
#   'virtualization',
#   'docker',
#   'amazon-web-services',
#   'kubernetes',
#   'api',
#   'rest',
#   'back-end',
#   'cloud-computing',
#   'english',
#   'cloud',
#   'mayor que mil',
#   'Sr Back-end Developer (Django)',
#   'Colombia'],
#  ['c-sharp',
#   'c',
#   'net',
#   'oracle',
#   'back-end',
#   'microservices',
#   'pl-sql',
#   'mayor que mil',
#   'Desarrollador .NET Proyecto de 6 Meses',
#   'Remote'],
#  ['node-js',
#   'python',
#   'virtualization',
#   'vue-js',
#   'docker',
#   'git',
#   'amazon-web-services',
#   'api',
#   'back-end',
#   'cloud-computing',
#   'javascript',
#   'cloud',
#   'front-end',
#   'full-stack',
#   'mayor que mil',
#   'Desarrollador Full-Stack',
#   'Chile'],
#  ['devops',
#   'angularjs',
#   'continuous-integration',
#   'postgresql',
#   'virtualization',
#   'docker',
#   'git',
#   'spring',
#   'continuous-deployment',
#   'amazon-web-services',
#   'kubernetes',
#   'jenkins',
#   'full-stack',
#   'android-testing',
#   'cloud-gcp',
#   'back-end',
#   'ci-cd',
#   'agile',
#   'cloud-computing',
#   'javascript',
#   'cloud',
#   'junit',
#   'angular',
#   'java',
#   'front-end',
#   'spring-boot',
#   'mayor que mil',
#   'Semi Senior Full-Stack Developer',
#   'Remote'],
#  ['devops',
#   'angularjs',
#   'continuous-integration',
#   'postgresql',
#   'virtualization',
#   'docker',
#   'git',
#   'spring',
#   'continuous-deployment',
#   'amazon-web-services',
#   'kubernetes',
#   'jenkins',
#   'full-stack',
#   'android-testing',
#   'cloud-gcp',
#   'back-end',
#   'ci-cd',
#   'agile',
#   'cloud-computing',
#   'javascript',
#   'cloud',
#   'junit',
#   'angular',
#   'java',
#   'front-end',
#   'spring-boot',
#   'mayor que mil',
#   'Senior Full-Stack Developer',
#   'Remote'],
#  ['angularjs',
#   'virtualization',
#   'amazon-web-services',
#   'full-stack',
#   'cloud-gcp',
#   'back-end',
#   'cloud-computing',
#   'english',
#   'javascript',
#   'cloud',
#   'angular',
#   'java',
#   'front-end',
#   'spring-boot',
#   'mayor que mil',
#   'Senior Full-Stack Developer (Java/angular)',
#   'Remote'],
#  ['node-js',
#   'angularjs',
#   'oracle',
#   'git',
#   'jasper-report',
#   'full-stack',
#   'rest',
#   'back-end',
#   'jboss',
#   'javascript',
#   'angular',
#   'java',
#   'front-end',
#   'spring-boot',
#   'mayor que mil',
#   'Desarrollador Full-Stack',
#   'Chile'],
#  ['excel',
#   'sql',
#   'python',
#   'back-end',
#   'mayor que mil',
#   'Software Engineer',
#   'Remote'],
#  ['uml',
#   'jee',
#   'oracle',
#   'jsf',
#   'api',
#   'back-end',
#   'javascript',
#   'java',
#   'soa',
#   'spring-boot',
#   'soap',
#   'linux',
#   'mayor que mil',
#   'Desarrollador J2EE (Hibrido)',
#   'Chile'],
#  ['sql',
#   'html5',
#   'python',
#   'css',
#   'git',
#   'flask',
#   'back-end',
#   'javascript',
#   'mayor que mil',
#   'Software Engineer',
#   'Remote'],
#  ['api', 'menor que 1500', 'Developer Advocate', 'Chile'],
#  ['html5',
#   'python',
#   'css',
#   'odoo',
#   'back-end',
#   'javascript',
#   'menor que 1500',
#   'Odoo Developer',
#   'Remote'],
#  ['mysql',
#   'php',
#   'virtualization',
#   'vue-js',
#   'docker',
#   'full-stack',
#   'back-end',
#   'laravel',
#   'javascript',
#   'front-end',
#   'security-engineer',
#   'menor que 1500',
#   'Programador Full-Stack',
#   'Remote'],
#  ['sql',
#   'devops',
#   'django',
#   'html5',
#   'python',
#   'css',
#   'virtualization',
#   'docker',
#   'git',
#   'bootstrap',
#   'api',
#   'rest',
#   'postman',
#   'back-end',
#   'ci-cd',
#   'javascript',
#   'menor que 1500',
#   'Desarrollador Python (Web)',
#   'Remote'],
#  ['nestjs',
#   'angularjs',
#   'git',
#   'microservices',
#   'kubernetes',
#   'api',
#   'full-stack',
#   'typescript',
#   'javascript',
#   'angular',
#   'front-end',
#   'mayor que mil',
#   'Full-Stack Angular Rest',
#   'Chile'],
#  ['mysql',
#   'nosql',
#   'nestjs',
#   'node-js',
#   'angularjs',
#   'oracle',
#   'go',
#   'postgresql',
#   'virtualization',
#   'golang',
#   'mongodb',
#   'amazon-web-services',
#   'full-stack',
#   'back-end',
#   'firebase',
#   'mobile',
#   'cloud-computing',
#   'typescript',
#   'javascript',
#   'cloud',
#   'angular',
#   'front-end',
#   'mayor que mil',
#   'Full-Stack',
#   'Chile'],
#  ['mysql',
#   'node-js',
#   'angularjs',
#   'php',
#   'codeigniter',
#   'virtualization',
#   'redux',
#   'mvc',
#   'mongodb',
#   'scrum',
#   'git',
#   'react',
#   'amazon-web-services',
#   'full-stack',
#   'rest',
#   'sonarqube',
#   'cloud-gcp',
#   'back-end',
#   'agile',
#   'cloud-computing',
#   'typescript',
#   'laravel',
#   'javascript',
#   'cloud',
#   'angular',
#   'front-end',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'sonarqube-14cb7487-289b-4f1b-ae29-a5fd66c7b505',
#   'mayor que mil',
#   'Desarrollador Full-Stack',
#   'Remote'],
#  ['tech-lead',
#   'english',
#   'cloud',
#   'security-engineer',
#   'back-end',
#   'agile',
#   'front-end',
#   'cloud-architecture',
#   'mayor que mil',
#   'Líder Técnico',
#   'Chile'],
#  ['python',
#   'git',
#   'back-end',
#   'data-engineer',
#   'java',
#   'machine-learning',
#   'ai',
#   'mayor que mil',
#   'Data Engineer',
#   'Remote'],
#  ['nosql',
#   'go',
#   'redux',
#   'golang',
#   'mongodb',
#   'react',
#   'microservices',
#   'back-end',
#   'english',
#   'front-end',
#   'mayor que mil',
#   'Golang Developer',
#   'Remote'],
#  ['git',
#   'microservices',
#   'spring',
#   'functional-programming',
#   'tdd',
#   'back-end',
#   'ci-cd',
#   'java',
#   'spring-boot',
#   'mayor que mil',
#   'Desarrollador Java (Spring)',
#   'Ecuador'],
#  ['ruby-on-rails',
#   'ruby',
#   'node-js',
#   'scala',
#   'microservices',
#   'data-architecture',
#   'graphql',
#   'api',
#   'sidekiq',
#   'rest',
#   'kafka',
#   'back-end',
#   'javascript',
#   'java',
#   'virtualization',
#   'docker',
#   'kubernetes',
#   'mayor que mil',
#   'Ruby on Rails Senior Developer',
#   'Remote'],
#  ['groovy',
#   'sap',
#   'abap',
#   'api',
#   'back-end',
#   'cloud',
#   'java',
#   'soap',
#   'erp',
#   'mayor que mil',
#   'Especialista de Intregración SAP',
#   'Remote'],
#  ['angularjs',
#   'html5',
#   'css',
#   'git',
#   'bootstrap',
#   'full-stack',
#   'back-end',
#   'javascript',
#   'angular',
#   'java',
#   'front-end',
#   'svn',
#   'node-js',
#   'oracle',
#   'maven',
#   'spring',
#   'tomcat',
#   'spring-boot',
#   'project-management',
#   'mayor que mil',
#   'Full-Stack Angular + Java',
#   'Remote'],
#  ['nestjs',
#   'node-js',
#   'css',
#   'virtualization',
#   'react',
#   'amazon-web-services',
#   'next-js',
#   'full-stack',
#   'cloud-gcp',
#   'back-end',
#   'cloud-computing',
#   'javascript',
#   'terraform',
#   'cloud',
#   'infrastructure-as-code',
#   'github',
#   'mayor que mil',
#   'Desarrollador Full-Stack Next.JS',
#   'Chile'],
#  ['responsive',
#   'css',
#   'git',
#   'bootstrap',
#   'front-end',
#   'diseno-ui',
#   'angularjs',
#   'javascript',
#   'angular',
#   'mayor que mil',
#   'Desarrollador Front-end',
#   'Remote'],
#  ['nosql',
#   'node-js',
#   'python',
#   'go',
#   'postgresql',
#   'golang',
#   'mongodb',
#   'react',
#   'next-js',
#   'full-stack',
#   'back-end',
#   'javascript',
#   'front-end',
#   'mayor que mil',
#   'Full-Stack Engineer',
#   'Remote'],
#  ['ruby-on-rails',
#   'angularjs',
#   'postgresql',
#   'javascript',
#   'angular',
#   'front-end',
#   'github',
#   'mayor que mil',
#   'Desarrollador Ruby on Rails',
#   'Remote'],
#  ['fastapi',
#   'python',
#   'virtualization',
#   'react',
#   'data-architecture',
#   'amazon-web-services',
#   'api',
#   'full-stack',
#   'dynamodb',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'javascript',
#   'cloud',
#   'infrastructure-as-code',
#   'cloudformation',
#   'github',
#   'mayor que mil',
#   'Desarrollador Full-Stack 100% Latam',
#   'Remote'],
#  ['devops',
#   'sonarqube',
#   'jira',
#   'ci-cd',
#   'tech-lead',
#   'agile',
#   'cloud',
#   'project-management',
#   'sonarqube-14cb7487-289b-4f1b-ae29-a5fd66c7b505',
#   'mayor que mil',
#   'Tech Lead',
#   'Remote'],
#  ['ruby-on-rails',
#   'microservices',
#   'javascript',
#   'software-analyst',
#   'mayor que mil',
#   'Desarrollador Ruby on Rails',
#   'Remote'],
#  ['mysql',
#   'oracle',
#   'php',
#   'vue-js',
#   'scrum',
#   'git',
#   'react',
#   'full-stack',
#   'back-end',
#   'agile',
#   'laravel',
#   'javascript',
#   'front-end',
#   'linux',
#   'menor que 1500',
#   'Desarrollador Full-Stack, Laravel + Vue.js',
#   'Remote'],
#  ['marketing',
#   'advertising',
#   'ingeniero-comercial',
#   'mayor que mil',
#   'Líder Marketing Latam (Pre y Post Natal)',
#   'Chile'],
#  ['marketing',
#   'facebook-ads',
#   'paid-media',
#   'menor que 1500',
#   'Performance Manager',
#   'Chile'],
#  ['project-management',
#   'paid-media',
#   'menor que 1500',
#   'Project Manager Paid Media',
#   'Remote'],
#  ['excel', 'marketing', 'menor que 1500', 'Marketing Lead (México)', 'Remote'],
#  ['diseno-ui',
#   'marketing',
#   'diseno-web',
#   'redes-sociales',
#   'figma',
#   'audiovisual',
#   'mayor que mil',
#   'Marketing Designer',
#   'Remote'],
#  ['analytics',
#   'marketing',
#   'project-management',
#   'crm',
#   'english',
#   'automatizacion',
#   'mayor que mil',
#   'Manager, Marketing Technology and Operations',
#   'Remote'],
#  ['marketing',
#   'project-management',
#   'digital-marketing',
#   'mayor que mil',
#   'Sr Manager, Acquisition Marketing',
#   'Remote'],
#  ['analytics',
#   'marketing',
#   'diseno-web',
#   'redes-sociales',
#   'adobe-suite',
#   'advertising',
#   'photoshop',
#   'english',
#   'menor que 1500',
#   'Community Manager',
#   'Chile'],
#  ['javascript',
#   'java',
#   'html5',
#   'css',
#   'php',
#   'seo',
#   'mysql',
#   'trafficker',
#   'full-stack',
#   'back-end',
#   'mayor que mil',
#   'Full-Stack / SEO',
#   'Chile'],
#  ['redes-sociales',
#   'graphic-design',
#   'advertising',
#   'mayor que mil',
#   'Director de Creatividad Social Media',
#   'Peru'],
#  ['data-analysis',
#   'marketing',
#   'menor que 1500',
#   'Ads Specialist (Colombia, México & Argentina)',
#   'Remote'],
#  ['sap',
#   'project-management',
#   'mayor que mil',
#   'Project Manager SAP S/4HANA Bilingüe',
#   'Remote'],
#  ['project-management', 'mayor que mil', 'Project Manager', 'Chile'],
#  ['product-manager',
#   'continual-improvement-process',
#   'menor que 1500',
#   'Líder de Portafolio/Product Manager',
#   'Chile'],
#  ['agile',
#   'scrum',
#   'scrum-master',
#   'jira',
#   'confluence',
#   'mayor que mil',
#   'Scrum Master',
#   'Remote'],
#  ['jira',
#   'product-owner',
#   'confluence',
#   'mayor que mil',
#   'Product Owner',
#   'Chile'],
#  ['agile', 'tech-lead', 'cloud', 'mayor que mil', 'Tech Lead', 'Chile'],
#  ['ux',
#   'analytics',
#   'diseno-web',
#   'sketch',
#   'product-manager',
#   'english',
#   'jira',
#   'educacion',
#   'mayor que mil',
#   'Product Manager',
#   'Remote'],
#  ['agile',
#   'sql',
#   'oracle',
#   'scrum',
#   'pl-sql',
#   'sql-server',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'mayor que mil',
#   'Configuración de Productos (Cdp)',
#   'Chile'],
#  ['analytics',
#   'agile',
#   'lean',
#   'big-data',
#   'scrum',
#   'tech-lead',
#   'cloud',
#   'mayor que mil',
#   'Project Leader',
#   'Chile'],
#  ['agile',
#   'scrum',
#   'api',
#   'swagger',
#   'postman',
#   'jira',
#   'product-owner',
#   'user-testing',
#   'mayor que mil',
#   'Product Owner Jr',
#   'Remote'],
#  ['agile',
#   'scrum',
#   'scrum-master',
#   'jira',
#   'confluence',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'mayor que mil',
#   'Scrum Master',
#   'Chile'],
#  ['project-management',
#   'ai',
#   'machine-learning',
#   'crm',
#   'machine-learning-engineer',
#   'erp',
#   'mayor que mil',
#   'Jefe de Proyecto',
#   'Chile'],
#  ['product-manager',
#   'product-owner',
#   'mayor que mil',
#   'Product Owner',
#   'Chile'],
#  ['agile', 'project-management', 'mayor que mil', 'PMO', 'Chile'],
#  ['agile',
#   'sql',
#   'project-management',
#   'english',
#   'jira',
#   'erp',
#   'sql-server',
#   'mayor que mil',
#   'PMO Bilingüe',
#   'Chile'],
#  ['agile',
#   'scrum',
#   'scrum-master',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'mayor que mil',
#   'Scrum Master',
#   'Remote'],
#  ['java',
#   'python',
#   'postgresql',
#   'sql',
#   'oracle',
#   'scala',
#   'bigquery',
#   'etl',
#   'english',
#   'back-end',
#   'cloud',
#   'data-architecture',
#   'sql-server',
#   'mayor que mil',
#   'Semi Senior Data Wrangler',
#   'Remote'],
#  ['python',
#   'sql',
#   'nosql',
#   'virtualization',
#   'big-data',
#   'amazon-web-services',
#   'ai',
#   'machine-learning',
#   'deep-learning',
#   'r',
#   'data-science',
#   'cloud-computing',
#   'keras',
#   'pytorch',
#   'back-end',
#   'cloud',
#   'machine-learning-engineer',
#   'data-architecture',
#   'mayor que mil',
#   'Data Scientist',
#   'Remote'],
#  ['java',
#   'python',
#   'redis',
#   'agile',
#   'mysql',
#   'postgresql',
#   'linux',
#   'nosql',
#   'scala',
#   'virtualization',
#   'amazon-web-services',
#   'mongodb',
#   'cloud-computing',
#   'api',
#   'elasticsearch',
#   'back-end',
#   'kafka',
#   'ansible',
#   'cloud-gcp',
#   'security-engineer',
#   'cloud',
#   'infrastructure-as-code',
#   'terraform',
#   'cloudformation',
#   'gitlab',
#   'github',
#   'data-architecture',
#   'mayor que mil',
#   'Data Ops',
#   'Remote'],
#  ['python',
#   'business-intelligence',
#   'ai',
#   'machine-learning',
#   'power-bi',
#   'data-science',
#   'keras',
#   'back-end',
#   'data-visualization',
#   'tableau',
#   'machine-learning-engineer',
#   'mayor que mil',
#   'Data Scientist',
#   'Chile'],
#  ['c',
#   'sql',
#   'sap',
#   'c-sharp',
#   'continuous-integration',
#   'project-management',
#   'maven',
#   'etl',
#   'jenkins',
#   'automatizacion',
#   'back-end',
#   'data-engineer',
#   'mayor que mil',
#   'Semi Senior/Senior DBA/Data Engineer',
#   'Remote'],
#  ['analytics',
#   'data-analysis',
#   'business-intelligence',
#   'data-visualization',
#   'tableau',
#   'mayor que mil',
#   'Senior Data Analyst',
#   'Chile'],
#  ['excel', 'english', 'menor que 1500', 'Data Operations Associate', 'Chile'],
#  ['data-analysis', 'sql', 'mayor que mil', 'Data Analyst', 'Chile'],
#  ['agile',
#   'virtualization',
#   'amazon-web-services',
#   'azure',
#   'power-bi',
#   'cloud-computing',
#   'cloud-gcp',
#   'data-visualization',
#   'cloud',
#   'data-governance',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'mayor que mil',
#   'Data Governance Specialist',
#   'Argentina'],
#  ['analytics',
#   'mysql',
#   'postgresql',
#   'data-analysis',
#   'sql',
#   'business-intelligence',
#   'bigquery',
#   'ai',
#   'machine-learning',
#   'etl',
#   'power-bi',
#   'data-science',
#   'data-visualization',
#   'tableau',
#   'security-engineer',
#   'user-testing',
#   'data-engineer',
#   'cloud',
#   'machine-learning-engineer',
#   'data-governance',
#   'data-architecture',
#   'mayor que mil',
#   'Tech Data Engineer',
#   'Remote'],
#  ['python',
#   'excel',
#   'sql',
#   'etl',
#   'power-bi',
#   'back-end',
#   'data-visualization',
#   'windows-server',
#   'software-analyst',
#   'menor que 1500',
#   'Operador de Base de Datos',
#   'Remote'],
#  ['python',
#   'data-analysis',
#   'sql',
#   'business-intelligence',
#   'virtualization',
#   'amazon-web-services',
#   'etl',
#   'cloud-computing',
#   'back-end',
#   'qlik-sense',
#   'data-visualization',
#   'tableau',
#   'cloud',
#   'mayor que mil',
#   'Ingeniero/a BI y Proyectos',
#   'Chile'],
#  ['data-analysis',
#   'sql',
#   'business-intelligence',
#   'virtualization',
#   'amazon-web-services',
#   'azure',
#   'power-bi',
#   'cloud-computing',
#   'qlik-sense',
#   'cloud-gcp',
#   'data-visualization',
#   'tableau',
#   'cloud',
#   'data-architecture',
#   'mayor que mil',
#   'Data Analyst',
#   'Chile'],
#  ['java',
#   'python',
#   'sql',
#   'web-server',
#   'scala',
#   'hadoop',
#   'big-data',
#   'etl',
#   'spark',
#   'apache-spark',
#   'nifi',
#   'back-end',
#   'data-engineer',
#   'cloud',
#   'data-architecture',
#   'mayor que mil',
#   'Data Engineer 🚀🌟',
#   'Chile'],
#  ['agile',
#   'mysql',
#   'postgresql',
#   'git',
#   'sql',
#   'business-intelligence',
#   'virtualization',
#   'amazon-web-services',
#   'scrum',
#   'spark',
#   'cloud-computing',
#   'apache-spark',
#   'api',
#   'postman',
#   'jira',
#   'data-visualization',
#   'tableau',
#   'ci-cd',
#   'cloud',
#   'infrastructure-as-code',
#   'terraform',
#   'confluence',
#   'data-architecture',
#   'sql-server',
#   'mayor que mil',
#   'Arquitecto de Datos',
#   'Remote'],
#  ['postgresql',
#   'sql',
#   'oracle',
#   'software-analyst',
#   'menor que 1500',
#   'Analista Desarrollador Data',
#   'Peru'],
#  ['business-intelligence',
#   'data-science',
#   'data-governance',
#   'cybersecurity-certifications',
#   'mayor que mil',
#   'Analista Gobierno de Datos (Híbrido)',
#   'Chile'],
#  ['analytics',
#   'nosql',
#   'virtualization',
#   'big-data',
#   'amazon-web-services',
#   'cloud-computing',
#   'dynamodb',
#   'security-engineer',
#   'cloud',
#   'mayor que mil',
#   'Big Data Analytics NoSQL',
#   'Remote'],
#  ['business-analyst', 'mayor que mil', 'Business Analyst', 'Remote'],
#  ['python',
#   'sql',
#   'business-intelligence',
#   'hadoop',
#   'virtualization',
#   'big-data',
#   'amazon-web-services',
#   'azure',
#   'r',
#   'data-science',
#   'spark',
#   'cloud-computing',
#   'apache-spark',
#   'back-end',
#   'cloud-gcp',
#   'data-visualization',
#   'tableau',
#   'cloud',
#   'data-architecture',
#   'mayor que mil',
#   'Consultor Data Science',
#   'Chile'],
#  ['python',
#   'data-analysis',
#   'sql',
#   'power-bi',
#   'back-end',
#   'data-visualization',
#   'menor que 1500',
#   'Data Analyst Junior',
#   'Chile'],
#  ['python',
#   'sql',
#   'english',
#   'back-end',
#   'mayor que mil',
#   'Python Engineer',
#   'Remote'],
#  ['sql', 'etl', 'menor que 1500', 'Ingeniero Jr. | ETL', 'Remote'],
#  ['python',
#   'analytics',
#   'data-analysis',
#   'sql',
#   'sap',
#   'business-intelligence',
#   'big-data',
#   'power-bi',
#   'english',
#   'back-end',
#   'data-visualization',
#   'erp',
#   'menor que 1500',
#   'Data Analyst',
#   'Peru'],
#  ['analytics',
#   'data-analysis',
#   'excel',
#   'marketing',
#   'sql',
#   'business-intelligence',
#   'etl',
#   'power-bi',
#   'data-visualization',
#   'mayor que mil',
#   'Ingeniero Power BI/SQL – Contrato Proyecto 6',
#   'Chile'],
#  ['virtualization',
#   'azure',
#   'amazon-web-services',
#   'cloud-gcp',
#   'cloud-computing',
#   'cloud',
#   'mayor que mil',
#   'Arquitecto Cloud',
#   'Remote'],
#  ['devops',
#   'scala',
#   'postgresql',
#   'azure',
#   'data-architecture',
#   'kubernetes',
#   'kafka',
#   'ci-cd',
#   'cloud-computing',
#   'english',
#   'terraform',
#   'cloud',
#   'java',
#   'infrastructure-as-code',
#   'sap',
#   'mayor que mil',
#   'Senior DevOps Bilingüe',
#   'Chile'],
#  ['qa',
#   'virtualization',
#   'azure',
#   'amazon-web-services',
#   'api',
#   'nifi',
#   'cloud-computing',
#   'cloud',
#   'project-management',
#   'security-engineer',
#   'mayor que mil',
#   'Jefe de Proyecto QA',
#   'Chile'],
#  ['sql',
#   'devops',
#   'python',
#   'virtualization',
#   'azure',
#   'amazon-web-services',
#   'kubernetes',
#   'cloud-gcp',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'english',
#   'terraform',
#   'cloud',
#   'infrastructure-as-code',
#   'gitlab',
#   'mayor que mil',
#   'DevOps Engineer 👾👾',
#   'Chile'],
#  ['devops',
#   'scrum',
#   'git',
#   'azure',
#   'data-science',
#   'jira',
#   'automatizacion',
#   'ci-cd',
#   'agile',
#   'mobile',
#   'cloud-computing',
#   'android',
#   'cloud',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'bitbucket',
#   'github',
#   'mayor que mil',
#   'Test Automation Engineer',
#   'Peru'],
#  ['groovy',
#   'devops',
#   'kubernetes',
#   'back-end',
#   'ci-cd',
#   'terraform',
#   'infrastructure-as-code',
#   'security-engineer',
#   'mayor que mil',
#   'DevOps Engineer (Semi Senior Colombia)',
#   'Remote'],
#  ['virtualization',
#   'amazon-web-services',
#   'cloud-computing',
#   'cloud',
#   'cloud-engineer',
#   'infrastructure-as-code',
#   'mayor que mil',
#   'Cloud Engineer',
#   'Remote'],
#  ['ux',
#   'virtualization',
#   'red-hat',
#   'security-engineer',
#   'linux',
#   'unix',
#   'mayor que mil',
#   'Administrador de Sistema',
#   'Chile'],
#  ['marketing',
#   'oracle',
#   'ventas',
#   'cloud',
#   'customer-experience',
#   'mayor que mil',
#   'Consultor Oracle CX',
#   'Chile'],
#  ['virtualization',
#   'azure',
#   'amazon-web-services',
#   'cloud-gcp',
#   'ci-cd',
#   'cloud-computing',
#   'cloud',
#   'mayor que mil',
#   'Ingeniero en Desarrollo Cloud',
#   'Chile'],
#  ['mysql',
#   'sql',
#   'oracle',
#   'python',
#   'postgresql',
#   'etl',
#   'sql-server',
#   'mariadb',
#   'back-end',
#   'data-analysis',
#   'security-engineer',
#   'linux',
#   'mayor que mil',
#   'Administrador de Bases de Datos (DBA)',
#   'Chile'],
#  ['excel',
#   'analytics',
#   'power-bi',
#   'crm',
#   'hubspot',
#   'english',
#   'data-visualization',
#   'menor que 1500',
#   'CRM Specialist',
#   'Chile'],
#  ['virtualization',
#   'docker',
#   'git',
#   'amazon-web-services',
#   'kubernetes',
#   'sre',
#   'cloud-computing',
#   'cloud',
#   'linux',
#   'mayor que mil',
#   'Site Reliability Engineer',
#   'Remote'],
#  ['lean',
#   'devops',
#   'continuous-integration',
#   'oracle',
#   'git',
#   'kubernetes',
#   'jenkins',
#   'jira',
#   'ci-cd',
#   'agile',
#   'cloud',
#   'mayor que mil',
#   'DevOps',
#   'Chile'],
#  ['qa',
#   'rest',
#   'postman',
#   'jira',
#   'functional-qa',
#   'functional-analyst',
#   'menor que 1500',
#   'Analista QA Funcional',
#   'Remote'],
#  ['devops',
#   'python',
#   'virtualization',
#   'data-architecture',
#   'amazon-web-services',
#   'ansible',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'cloud',
#   'software-architect',
#   'linux',
#   'mayor que mil',
#   'Especialista en Administración de Infraestruc',
#   'Remote'],
#  ['mysql',
#   'html5',
#   'php',
#   'css',
#   'vue-js',
#   'git',
#   'api',
#   'back-end',
#   'laravel',
#   'javascript',
#   'front-end',
#   'menor que 1500',
#   'Soporte Junior Laravel/Vue.js',
#   'Chile'],
#  ['qa', 'jira', 'agile', 'mayor que mil', 'Analista QA', 'Chile'],
#  ['nosql',
#   'sql',
#   'postgresql',
#   'virtualization',
#   'mongodb',
#   'etl',
#   'azure',
#   'amazon-web-services',
#   'sql-server',
#   'dynamodb',
#   'cloud-gcp',
#   'mariadb',
#   'cloud-computing',
#   'cloud',
#   'mayor que mil',
#   'DBA',
#   'Remote'],
#  ['qa', 'menor que 1500', 'Analista QA', 'Chile'],
#  ['qa',
#   'devops',
#   'azure',
#   'selenium',
#   'tdd',
#   'android-testing',
#   'postman',
#   'ci-cd',
#   'bdd',
#   'cloud-computing',
#   'testing-frameworks',
#   'cloud',
#   'junit',
#   'mayor que mil',
#   'Quality Assurance Lead',
#   'Chile'],
#  ['devops',
#   'virtualization',
#   'docker',
#   'azure',
#   'kubernetes',
#   'ci-cd',
#   'cloud-computing',
#   'terraform',
#   'cloud',
#   'infrastructure-as-code',
#   'linux',
#   'gitlab',
#   'mayor que mil',
#   'DevOps Cloud',
#   'Remote'],
#  ['cloud-gcp',
#   'mayor que mil',
#   'Ingeniero de Infraestructura y Plataformas',
#   'Chile'],
#  ['net',
#   'oracle',
#   'virtualization',
#   'scrum',
#   'git',
#   'azure',
#   'amazon-web-services',
#   'back-end',
#   'agile',
#   'cloud-computing',
#   'pl-sql',
#   'cloud',
#   'java',
#   'menor que 1500',
#   'Administrador de Aplicaciones Medium Híbrido',
#   'Colombia'],
#  ['qa',
#   'data-science',
#   'user-testing',
#   'qa-engineer',
#   'english',
#   'mayor que mil',
#   'QA Engineer',
#   'Chile'],
#  ['devops',
#   'c',
#   'virtualization',
#   'amazon-web-services',
#   'educacion',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'cloud',
#   'infrastructure-as-code',
#   'software-architect',
#   'cloud-architecture',
#   'administration',
#   'mayor que mil',
#   'AWS Cloud Architecture Lead',
#   'Remote'],
#  ['groovy',
#   'devops',
#   'python',
#   'virtualization',
#   'docker',
#   'git',
#   'microservices',
#   'kubernetes',
#   'api',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'terraform',
#   'cloud',
#   'infrastructure-as-code',
#   'linux',
#   'administration',
#   'splunk',
#   'mayor que mil',
#   'Middle DevOps Engineer',
#   'Remote'],
#  ['python',
#   'virtualization',
#   'docker',
#   'git',
#   'microservices',
#   'amazon-web-services',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'cloud',
#   'infrastructure-as-code',
#   'linux',
#   'gitlab',
#   'github',
#   'kubernetes',
#   'mayor que mil',
#   'Rse Engineer',
#   'Remote'],
#  ['qa', 'ux', 'mayor que mil', 'Analista de Pruebas (Uat)', 'Remote'],
#  ['mysql',
#   'web-server',
#   'postgresql',
#   'virtualization',
#   'docker',
#   'git',
#   'azure',
#   'kubernetes',
#   'nginx',
#   'ci-cd',
#   'siem',
#   'cloud-computing',
#   'english',
#   'cloud',
#   'security-engineer',
#   'linux',
#   'bitbucket',
#   'siem-c1092d5c-11b9-4644-a424-7c3a3cc53224',
#   'menor que 1500',
#   'Analista de Infraestructura',
#   'Remote'],
#  ['rest',
#   'cloud',
#   'mayor que mil',
#   'Ingeniero Sistemas Operacion Cloud TI',
#   'Chile'],
#  ['svn',
#   'sql',
#   'continuous-integration',
#   'jenkins',
#   'jira',
#   'gitlab',
#   'menor que 1500',
#   'Analista de Calidad de Software Proyecto',
#   'Peru'],
#  ['qa',
#   'jira',
#   'agile',
#   'mayor que mil',
#   'Consultant QA (Zephyr Eazybi 🐱\u200d🚀)',
#   'Chile'],
#  ['sql',
#   'oracle',
#   'mayor que mil',
#   'Jefe de Explotación de Sistemas TI',
#   'Chile'],
#  ['virtualization',
#   'amazon-web-services',
#   'kubernetes',
#   'sre',
#   'cloud-computing',
#   'english',
#   'cloud',
#   'security-engineer',
#   'mayor que mil',
#   'Site Reliability Engineer (SRE)',
#   'Remote'],
#  ['usabilidad',
#   'qa',
#   'continuous-integration',
#   'scrum',
#   'selenium',
#   'jenkins',
#   'tdd',
#   'automatizacion',
#   'ci-cd',
#   'agile',
#   'testing-frameworks',
#   'machine-learning',
#   'jmeter',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'audit',
#   'gitlab',
#   'ai',
#   'diseno-ui',
#   'mayor que mil',
#   'Lider QA',
#   'Chile'],
#  ['nestjs',
#   'node-js',
#   'devops',
#   'virtualization',
#   'vue-js',
#   'docker',
#   'amazon-web-services',
#   'express',
#   'back-end',
#   'ci-cd',
#   'cloud-computing',
#   'typescript',
#   'javascript',
#   'cloud',
#   'front-end',
#   'gitlab',
#   'github',
#   'mayor que mil',
#   'DevOps',
#   'Chile'],
#  ['usabilidad',
#   'qa',
#   'scrum',
#   'api',
#   'postman',
#   'jira',
#   'agile',
#   'confluence',
#   'diseno-ui',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'menor que 1500',
#   'Quality Assurance Analyst',
#   'Chile'],
#  ['qa',
#   'devops',
#   'azure',
#   'selenium',
#   'data-science',
#   'tdd',
#   'ci-cd',
#   'karate',
#   'user-testing',
#   'cloud-computing',
#   'testing-frameworks',
#   'cloud',
#   'mayor que mil',
#   'Ingeniera/o QA',
#   'Chile'],
#  ['qa',
#   'qa-automation',
#   'selenium',
#   'tdd',
#   'testing-frameworks',
#   'python',
#   'git',
#   'back-end',
#   'java',
#   'menor que 1500',
#   'QA Automation Jr',
#   'Chile'],
#  ['qa',
#   'qa-automation',
#   'selenium',
#   'tdd',
#   'testing-frameworks',
#   'devops',
#   'python',
#   'azure',
#   'api',
#   'postman',
#   'back-end',
#   'ci-cd',
#   'karate',
#   'cloud-computing',
#   'cloud',
#   'java',
#   'soap',
#   'mayor que mil',
#   'QA Automation SSR / Sr',
#   'Chile'],
#  ['qa',
#   'qa-automation',
#   'rest',
#   'automatizacion',
#   'user-testing',
#   'agile',
#   'web-service',
#   'mayor que mil',
#   'QA Automation Engineer',
#   'Remote'],
#  ['qa',
#   'ux',
#   'devops',
#   'planning',
#   'azure',
#   'ci-cd',
#   'agile',
#   'cloud-computing',
#   'cloud',
#   'mayor que mil',
#   'Analista QA',
#   'Chile'],
#  ['devops',
#   'angularjs',
#   'continuous-integration',
#   'oracle',
#   'jenkins',
#   'back-end',
#   'ci-cd',
#   'javascript',
#   'cloud',
#   'angular',
#   'java',
#   'front-end',
#   'linux',
#   'confluence',
#   'gitlab',
#   'mayor que mil',
#   'DevOps Engineer',
#   'Chile'],
#  ['oracle',
#   'database-administrator',
#   'mayor que mil',
#   'Administrador de Base de Datos (Oracle)',
#   'Chile'],
#  ['net',
#   'css',
#   'agile',
#   'sql',
#   'scrum',
#   'bootstrap',
#   'back-end',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'menor que 1500',
#   'Desarrollador Back-end Aplicaciones Móviles',
#   'Bolivia'],
#  ['javascript',
#   'android',
#   'ios',
#   'git',
#   'json',
#   'react-native',
#   'flutter',
#   'mobile',
#   'mayor que mil',
#   'Desarrollador Front App',
#   'Chile'],
#  ['front-end',
#   'flutter',
#   'security-engineer',
#   'mobile',
#   'mayor que mil',
#   'Desarrollador Front-end Semi Senior en Flutter',
#   'Remote'],
#  ['javascript',
#   'android',
#   'ios',
#   'nosql',
#   'mongodb',
#   'redux',
#   'react-native',
#   'back-end',
#   'mobile',
#   'firebase',
#   'mayor que mil',
#   'Programador de Aplicaciones React Native',
#   'Chile'],
#  ['react-native',
#   'mobile',
#   'mayor que mil',
#   'Semi Sr/Senior React Native Developer',
#   'Ecuador'],
#  ['ios',
#   'objective-c',
#   'swift',
#   'continuous-integration',
#   'api',
#   'cocoapods',
#   'mobile',
#   'firebase',
#   'mayor que mil',
#   'Desarrollador iOS',
#   'Chile'],
#  ['android',
#   'ios',
#   'git',
#   'rest',
#   'virtualization',
#   'amazon-web-services',
#   'cloud-computing',
#   'tdd',
#   'english',
#   'flutter',
#   'cloud-gcp',
#   'ci-cd',
#   'mobile',
#   'user-testing',
#   'dart',
#   'cloud',
#   'mayor que mil',
#   'Software Engineer Flutter',
#   'Chile'],
#  ['javascript',
#   'android',
#   'ios',
#   'rest',
#   'continuous-integration',
#   'react-native',
#   'english',
#   'ci-cd',
#   'mobile',
#   'debugging',
#   'websockets',
#   'mayor que mil',
#   'React Native Engineer',
#   'Remote'],
#  ['android',
#   'go',
#   'golang',
#   'kotlin',
#   'mobile',
#   'debugging',
#   'mayor que mil',
#   'Mobile Engineer(kotlin)',
#   'Remote'],
#  ['ios',
#   'mobile',
#   'debugging',
#   'mayor que mil',
#   'iOS/Tvos Developer',
#   'Remote'],
#  ['ruby-on-rails',
#   'android',
#   'ios',
#   'react-native',
#   'mobile',
#   'firebase',
#   'software-analyst',
#   'mayor que mil',
#   'Desarrollador React Native',
#   'Chile'],
#  ['java',
#   'android',
#   'agile',
#   'front-end',
#   'git',
#   'scrum',
#   'cloud-computing',
#   'api',
#   'kotlin',
#   'back-end',
#   'mobile',
#   'firebase',
#   'dagger',
#   'cloud',
#   'gradle',
#   'jetpack',
#   'mayor que mil',
#   'Desarrollador Front-end Android',
#   'Bolivia'],
#  ['android',
#   'kotlin',
#   'mobile',
#   'jetpack',
#   'mayor que mil',
#   'Desarrollador Android Kotlin',
#   'Chile'],
#  ['javascript',
#   'android',
#   'ios',
#   'agile',
#   'git',
#   'scrum',
#   'api',
#   'typescript',
#   'flutter',
#   'mobile',
#   'dart',
#   'mayor que mil',
#   'Flutter Mobile Developer',
#   'Remote'],
#  ['ios',
#   'objective-c',
#   'swift',
#   'english',
#   'cocoapods',
#   'ci-cd',
#   'mobile',
#   'user-testing',
#   'mayor que mil',
#   'Junior iOS Software Engineer',
#   'Remote'],
#  ['virtualization',
#   'amazon-web-services',
#   'react-native',
#   'cloud-computing',
#   'english',
#   'mobile',
#   'cloud',
#   'mayor que mil',
#   'React Native Developer',
#   'Remote'],
#  ['ios',
#   'agile',
#   'rest',
#   'swift',
#   'microservices',
#   'ci-cd',
#   'mobile',
#   'swiftui',
#   'gitlab',
#   'mayor que mil',
#   'Desarrollador Mobile iOS',
#   'Mexico'],
#  ['javascript',
#   'ios',
#   'diseno-ui',
#   'html5',
#   'css',
#   'responsive',
#   'agile',
#   'front-end',
#   'git',
#   'diseno-web',
#   'react',
#   'scrum',
#   'react-native',
#   'es6',
#   'figma',
#   'mobile',
#   'menor que 1500',
#   'Front-end Developer React Native',
#   'Remote'],
#  ['ios',
#   'agile',
#   'git',
#   'swift',
#   'mobile',
#   'user-testing',
#   'design-systems',
#   'swiftui',
#   'gitlab',
#   'mayor que mil',
#   'iOS Engineer Senior',
#   'Remote'],
#  ['javascript',
#   'diseno-ui',
#   'html5',
#   'css',
#   'responsive',
#   'agile',
#   'front-end',
#   'git',
#   'diseno-web',
#   'react',
#   'scrum',
#   'react-native',
#   'es6',
#   'figma',
#   'mobile',
#   'menor que 1500',
#   'Front-end Developer React Native Perú',
#   'Remote'],
#  ['excel',
#   'e-commerce',
#   'menor que 1500',
#   'Administrativo Logístico',
#   'Remote'],
#  ['excel',
#   'customer-service',
#   'ventas',
#   'jira',
#   'menor que 1500',
#   'Analista Administrativo 🤯',
#   'Chile'],
#  ['excel', 'menor que 1500', 'Ejecutivo de Facturación y Cobranzas', 'Remote'],
#  ['agile',
#   'scrum',
#   'crm',
#   'scrum-master',
#   'erp',
#   'mayor que mil',
#   'Gerente de Proyectos Senior',
#   'Colombia'],
#  ['analytics',
#   'marketing',
#   'advertising',
#   'english',
#   'desarrollo-organizacional',
#   'menor que 1500',
#   'Digital Culture Coordinator',
#   'Chile'],
#  ['bizagi-modeler',
#   'continual-improvement-process',
#   'process-consultant',
#   'mayor que mil',
#   'Analista de Procesos',
#   'Remote'],
#  ['excel', 'menor que 1500', 'Office Manager', 'Chile'],
#  ['excel',
#   'power-bi',
#   'data-visualization',
#   'cisco',
#   'menor que 1500',
#   'Controller Call Center (Gtr)',
#   'Chile'],
#  ['agile',
#   'scrum',
#   'scrum-master',
#   'jira',
#   'confluence',
#   'kanban-cbe618f9-934b-4c01-87ae-4d0c7093da2b',
#   'mayor que mil',
#   'Scrum Máster Senior',
#   'Remote'],
#  ['customer-service',
#   'soporte-tecnico',
#   'menor que 1500',
#   'Analista Back Office',
#   'Remote'],
#  ['agile',
#   'sql',
#   'project-management',
#   'jira',
#   'sql-server',
#   'mayor que mil',
#   'PMO🐱\u200d👤 (Rubro Seguros) ☝',
#   'Chile'],
#  ['css',
#   'project-management',
#   'erp',
#   'accounting',
#   'audit',
#   'menor que 1500',
#   'Project Manager',
#   'Chile'],
#  ['accounting', 'menor que 1500', 'Analista de Operaciones Junior', 'Chile'],
#  ['english', 'mayor que mil', 'Administrador de Contratos TI', 'Chile'],
#  ['sap',
#   'english',
#   'erp',
#   'continual-improvement-process',
#   'mayor que mil',
#   'Ingeniero en Mantenimiento (Mejora Continua)',
#   'Remote'],
#  ['crm',
#   'hubspot',
#   'onboarding-specialist',
#   'mayor que mil',
#   'Onboarding Specialist',
#   'Chile'],
#  ['ventas',
#   'kam',
#   'english',
#   'mayor que mil',
#   'Key Account Manager (KAM)',
#   'Remote'],
#  ['crm',
#   'ventas',
#   'kam',
#   'menor que 1500',
#   'Key Account Manager (Agri)',
#   'Chile'],
#  ['ventas',
#   'kam',
#   'saas',
#   'mayor que mil',
#   'Key Account Manager Tcit',
#   'Chile'],
#  ['crm', 'hubspot', 'mayor que mil', 'Gerente Comercial', 'Chile'],
#  ['marketing', 'menor que 1500', 'SDR Outbound', 'Chile'],
#  ['marketing', 'ventas', 'menor que 1500', 'Ejecutivo Comercial TI', 'Chile'],
#  ['investment', 'mayor que mil', 'Asesor de Inversiones', 'Remote'],
#  ['marketing',
#   'ventas',
#   'administration',
#   'menor que 1500',
#   'Ejecutivo de Ventas',
#   'Chile'],
#  ['agile',
#   'excel',
#   'marketing',
#   'sap',
#   'oracle',
#   'virtualization',
#   'amazon-web-services',
#   'crm',
#   'director-de-cuentas',
#   'ventas',
#   'kam',
#   'cloud-computing',
#   'salesforce',
#   'growth',
#   'automatizacion',
#   'user-testing',
#   'hubspot',
#   'cloud',
#   'bpm',
#   'mayor que mil',
#   'Account Manager BDM Ventas TI Banca',
#   'Chile'],
#  ['crm',
#   'ventas',
#   'hubspot',
#   'menor que 1500',
#   'Agente de Ventas (Prospección)',
#   'Remote'],
#  ['crm',
#   'ventas',
#   'saas',
#   'hubspot',
#   'gsuite',
#   'menor que 1500',
#   'Agente de Seguros',
#   'Remote'],
#  ['ventas',
#   'english',
#   'continual-improvement-process',
#   'menor que 1500',
#   'Business Developement Representative',
#   'Remote'],
#  ['ventas',
#   'telemarketing',
#   'menor que 1500',
#   'Sales Development Representative Colombia',
#   'Remote'],
#  ['ejecutivo-de-cuentas',
#   'ventas',
#   'desarrollo-organizacional',
#   'menor que 1500',
#   'Ejecutivo de Cuentas Alianzas Estratégicas',
#   'Mexico'],
#  ['crm',
#   'ventas',
#   'saas',
#   'salesforce',
#   'hubspot',
#   'mayor que mil',
#   'Account Executive',
#   'Remote'],
#  ['crm',
#   'ventas',
#   'salesforce',
#   'hubspot',
#   'menor que 1500',
#   'Sales Development Representative',
#   'Remote'],
#  ['director-de-cuentas',
#   'ingeniero-comercial',
#   'english',
#   'security-engineer',
#   'cloud',
#   'mayor que mil',
#   'Account Manager con Foco en Grandes Empresas',
#   'Chile'],
#  ['marketing',
#   'crm',
#   'ventas',
#   'saas',
#   'english',
#   'mayor que mil',
#   'Account Executive Mex',
#   'Mexico'],
#  ['ventas', 'kam', 'mayor que mil', 'Key Account Manager', 'Mexico'],
#  ['crm',
#   'ventas',
#   'menor que 1500',
#   'Business Development Representative',
#   'Remote'],
#  ['ventas', 'mayor que mil', 'Representante de Ventas de Software', 'Remote'],
#  ['linux',
#   'english',
#   'cloud',
#   'office-365',
#   'mayor que mil',
#   'Especialista 365 (Office Suite)',
#   'Colombia'],
#  ['excel',
#   'ventas',
#   'ingeniero-comercial',
#   'english',
#   'mayor que mil',
#   'Consultor TI',
#   'Chile'],
#  ['mysql',
#   'oracle',
#   'linux',
#   'soporte-tecnico',
#   'menor que 1500',
#   'Soporte Técnico',
#   'Chile'],
#  ['python',
#   'git',
#   'django',
#   'virtualization',
#   'docker',
#   'flask',
#   'soporte-tecnico',
#   'back-end',
#   'fastapi',
#   'menor que 1500',
#   'Junior Software Support Developer',
#   'Chile'],
#  ['excel',
#   'devops',
#   'azure',
#   'power-bi',
#   'cloud-computing',
#   'jira',
#   'data-visualization',
#   'ci-cd',
#   'cloud',
#   'menor que 1500',
#   'Analista Gestion Incidentes TI',
#   'Chile'],
#  ['linux',
#   'security-engineer',
#   'audit',
#   'nist',
#   'cybersecurity-certifications',
#   'mayor que mil',
#   'IT Security Analyst',
#   'Chile'],
#  ['virtualization',
#   'amazon-web-services',
#   'cloud-computing',
#   'english',
#   'security-engineer',
#   'ethical-hacking',
#   'cloud',
#   'cybersecurity-certifications',
#   'mayor que mil',
#   'Ingeniero de Seguridad TI',
#   'Chile'],
#  ['english',
#   'security-engineer',
#   'cloud',
#   'mayor que mil',
#   'Especialista de Seguridad Cloud',
#   'Remote'],
#  ['analytics',
#   'excel',
#   'business-intelligence',
#   'power-bi',
#   'data-visualization',
#   'tableau',
#   'business-analyst',
#   'mayor que mil',
#   'Business Analyst Riesgo y Fraude 😎\u200b✨\u200b',
#   'Chile'],
#  ['devops',
#   'security-engineer',
#   'ci-cd',
#   'siem',
#   'siem-c1092d5c-11b9-4644-a424-7c3a3cc53224',
#   'nist',
#   'cybersecurity-certifications',
#   'mayor que mil',
#   'Ingeniero de Ciberseguridad',
#   'Chile'],
#  ['security-engineer',
#   'cisco',
#   'mayor que mil',
#   'Arquitecto de Redes Ciberseguridad',
#   'Remote'],
#  ['saas',
#   'english',
#   'security-engineer',
#   'csirt',
#   'siem',
#   'soc',
#   'cloud',
#   'siem-c1092d5c-11b9-4644-a424-7c3a3cc53224',
#   'mayor que mil',
#   'Analista SOC (Inglés Avanzado)',
#   'Chile'],
#  ['saas',
#   'english',
#   'security-engineer',
#   'csirt',
#   'siem',
#   'soc',
#   'cloud',
#   'siem-c1092d5c-11b9-4644-a424-7c3a3cc53224',
#   'mayor que mil',
#   'Analista Ciberseguridad (Inglés Avanzado)',
#   'Chile'],
#  ['linux',
#   'english',
#   'security-engineer',
#   'cloud',
#   'audit',
#   'unix',
#   'nist',
#   'cybersecurity-certifications',
#   'mayor que mil',
#   'Auditor TI (Controles Ciberseguridad)',
#   'Chile'],
#  ['sql',
#   'sap',
#   'oracle',
#   'linux',
#   'business-intelligence',
#   'security-engineer',
#   'pl-sql',
#   'erp',
#   'audit',
#   'mayor que mil',
#   'Auditor Riesgo Tecnológico (Proyecto)',
#   'Chile'],
#  ['security-engineer',
#   'ethical-hacking',
#   'cybersecurity-certifications',
#   'mayor que mil',
#   'Especialista en Ethical Hacking',
#   'Chile'],
#  ['python',
#   'sql',
#   'virtualization',
#   'docker',
#   'ai',
#   'machine-learning',
#   'english',
#   'sre',
#   'back-end',
#   'ci-cd',
#   'machine-learning-engineer',
#   'unix',
#   'mayor que mil',
#   'ML Engineer Mid Senior',
#   'Chile'],
#  ['python',
#   'virtualization',
#   'docker',
#   'ai',
#   'machine-learning',
#   'data-science',
#   'english',
#   'keras',
#   'pytorch',
#   'back-end',
#   'machine-learning-engineer',
#   'fastapi',
#   'mayor que mil',
#   'Genai Engineer',
#   'Chile'],
#  ['python',
#   '3d',
#   'ai',
#   'machine-learning',
#   'computer-vision',
#   'back-end',
#   'teaching',
#   'educacion',
#   'machine-learning-engineer',
#   'menor que 1500',
#   'Computer Vision Engineer',
#   'Remote'],
#  ['python',
#   'virtualization',
#   'big-data',
#   'amazon-web-services',
#   'azure',
#   'ai',
#   'machine-learning',
#   'deep-learning',
#   'data-science',
#   'cloud-computing',
#   'computer-vision',
#   'english',
#   'back-end',
#   'cloud-gcp',
#   'cloud',
#   'machine-learning-engineer',
#   'mayor que mil',
#   'Computer Vision Consultant',
#   'Remote'],
#  ['marketing',
#   'trafficker',
#   'paid-media',
#   'menor que 1500',
#   'Planificador de Medios Digitales Semi Senior',
#   'Chile'],
#  ['copywriting',
#   'advertising',
#   'crm',
#   'content-creation',
#   'hubspot',
#   'menor que 1500',
#   'Content Manager',
#   'Chile'],
#  ['advertising',
#   'security-engineer',
#   'mayor que mil',
#   'Coordinador de Interfaces Cctv Scada',
#   'Chile'],
#  ['advertising',
#   'security-engineer',
#   'mayor que mil',
#   'Ingeniero Sistemas Conectividad Comunicación',
#   'Chile']]

# %%
perksArray = []
for _, row in jobsDf.iterrows():
    perksInJob = []
